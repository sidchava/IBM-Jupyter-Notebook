# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Siddharth Chava__ <br>
# Student aspiring for data scientist

# %% [markdown]
# _I am interested in data science because I am good at math and I love analyzing data to help find trends and patterns to make better decisions_

# %% [markdown]
# ### This code is going to add my bills for the week and give me a total

# %%
13 + 24.5 + 10 + 12 + 120 + 15.5 + 67 + 82 + 12
# Out:
# 356.0

# %% [markdown]
# 1. This table will show the Days of the Week and how much I spent
# 1. From this table, I can see which days I spend the most money
# 1. After looking at which day is the most, I will focus my efforts on spending less that day <br>
# |Mon|Tues|Wed|Thurs|Fri|Sat|Sun|
# |---|---|---|---|---|---|---|
# |13|14|35|56|12|98|39|<br>
# ***
# Jupyter Notebooks are cool
# ***
